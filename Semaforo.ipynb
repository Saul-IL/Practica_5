# %%
s=(input("Qué color ve, agreguelo en MAYUSCULAS "))

if s=="VERDE":
    print("AVANZAR ")
    print(s)

elif s=="AMARILLO":
    print("PRECAUCIÓN")
    print(s)

elif s=="ROJO":
    print("ALTO")
    print(s)

else :
    print("No se puede realizar")
    print(s)
# Out:
# Qué color ve, agreguelo en MAYUSCULAS ROJO
# ALTO
# ROJO
